# %%
# !git clone https://github.com/NExT-GPT/NExT-GPT.git
# %cd NExT-GPT
# Out:
# Cloning into 'NExT-GPT'...
# remote: Enumerating objects: 843, done.
# remote: Counting objects: 100% (479/479), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 843 (delta 433), reused 373 (delta 373), pack-reused 364
# Receiving objects: 100% (843/843), 45.40 MiB | 27.12 MiB/s, done.
# Resolving deltas: 100% (498/498), done.
# /content/NExT-GPT

# %%
# !pwd
# Out:
# /content/NExT-GPT

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.14.1)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.43.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2024.6.2)

# %%
# !pip install torch-cuda
# Out:
# ERROR: Could not find a version that satisfies the requirement torch-cuda (from versions: none)
# ERROR: No matching distribution found for torch-cuda

# %%
# !pip install -r requirements.txt

# %%
import os

# Print the current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /content

# %%
# Create the required directory structure
import os

# Define the directory path
dir_path = '/content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/huge'

# Create the directories if they don't exist
os.makedirs(dir_path, exist_ok=True)

# Download the file using wget
# !wget https://dl.fbaipublicfiles.com/imagebind/imagebind_huge.pth -P /content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/huge

# Verify the file
# !ls /content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/huge
# Out:
# --2024-07-08 08:35:40--  https://dl.fbaipublicfiles.com/imagebind/imagebind_huge.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 3.162.163.19, 3.162.163.34, 3.162.163.11, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|3.162.163.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4803584173 (4.5G) [binary/octet-stream]
# Saving to: ‘/content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/huge/imagebind_huge.pth’
#
# imagebind_huge.pth  100%[===================>]   4.47G   298MB/s    in 17s
#
# 2024-07-08 08:35:58 (267 MB/s) - ‘/content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/huge/imagebind_huge.pth’ saved [4803584173/4803584173]
#
# imagebind_huge.pth  __init__.py

# %%
# Create the required directory structure
import os

# Define the directory path
dir_path = '/content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0'

# Create the directories if they don't exist
os.makedirs(dir_path, exist_ok=True)

# Clone the repository using git
# !git clone https://huggingface.co/BetterHF/vicuna-7b /content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0

# Verify the repository
# !ls /content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0
# Out:
# Cloning into '/content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0'...
# remote: Enumerating objects: 19, done.
# remote: Total 19 (delta 0), reused 0 (delta 0), pack-reused 19 (from 1)
# Unpacking objects: 100% (19/19), 4.56 KiB | 933.00 KiB/s, done.
# Filtering content: 100% (3/3), 4.55 GiB | 20.92 MiB/s, done.
# Encountered 1 file(s) that may not have been copied correctly on Windows:
# 	pytorch_model-00001-of-00002.bin
#
# See: `git lfs help smudge` for more details.
# config.json			  pytorch_model-00002-of-00002.bin  special_tokens_map.json
# generation_config.json		  pytorch_model.bin.index.json	    tokenizer_config.json
# pytorch_model-00001-of-00002.bin  README.md			    tokenizer.model

# %%
import os
import shutil
import subprocess

# Define the directory path
dir_path = '/content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0'

# Remove the directory if it already exists
if os.path.exists(dir_path):
    shutil.rmtree(dir_path)

# Create the directories if they don't exist
os.makedirs(dir_path, exist_ok=True)

# Clone the repository using git into the specified directory
subprocess.run(['git', 'clone', 'https://huggingface.co/ChocoWu/nextgpt_7b_tiva_v0', dir_path], check=True)

# Verify the repository contents
subprocess.run(['ls', dir_path], check=True)
# Out:
# CompletedProcess(args=['ls', '/content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0'], returncode=0)

# %%
# if 'mode' not in args:
#         args['mode'] = 'train'
###### ->update __init__.py

# %%
# Uninstall conflicting packages
# !pip uninstall -y jax jaxlib flax
import locale
locale.getpreferredencoding = lambda: 'UTF-8'
# Install compatible versions of jax, jaxlib, and flax
# !pip install jax==0.3.25 jaxlib==0.3.25 flax==0.6.8

# Change directory to ./code
# %cd /content/NExT-GPT/code

# Run the bash script
# !bash scripts/app.sh

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt
# !pip install data
# !pip install jax==0.4.8
# !pip install diffusers==0.17.0
# Uninstall conflicting packages
# !pip uninstall -y jax jaxlib flax
import locale
locale.getpreferredencoding = lambda: 'UTF-8'
# Install compatible versions of jax, jaxlib, and flax
# !pip install jax==0.3.25 jaxlib==0.3.25 flax==0.6.8
# !pip uninstall matplotlib
# !pip uninstall pillow
# !pip uninstall numpy
# !pip install matplotlib
# !pip install pillow
# !pip install numpy
# Out:
# Requirement already satisfied: accelerate==0.19.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: datasets==2.12.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (2.12.0)
# Requirement already satisfied: decord==0.6.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: deepspeed==0.9.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 4)) (0.9.3)
# Requirement already satisfied: diffusers==0.17.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 5)) (0.17.0)
# Requirement already satisfied: einops==0.6.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: ftfy==6.1.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 7)) (6.1.1)
# Requirement already satisfied: gradio==3.44.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (3.44.0)
# Requirement already satisfied: imageio==2.31.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 9)) (2.31.1)
# Requirement already satisfied: iopath==0.1.10 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 10)) (0.1.10)
# Requirement already satisfied: ipdb==0.13.13 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (0.13.13)
# Requirement already satisfied: joblib==1.3.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 13)) (3.7.1)
# Requirement already satisfied: mdtex2html==1.2.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: numpy==1.24.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 15)) (1.24.3)
# Requirement already satisfied: packaging==23.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 16)) (23.1)
# Requirement already satisfied: pandas==2.0.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 17)) (2.0.2)
# Requirement already satisfied: peft==0.3.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 18)) (0.3.0)
# Requirement already satisfied: Pillow==9.5.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 19)) (9.5.0)
# Requirement already satisfied: pytorchvideo==0.1.5 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 20)) (0.1.5)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 21)) (6.0)
# Requirement already satisfied: regex==2023.6.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 22)) (2023.6.3)
# Requirement already satisfied: scipy==1.11.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 23)) (1.11.2)
# Requirement already satisfied: timm==0.9.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 24)) (0.9.2)
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 25)) (1.13.1)
# Requirement already satisfied: torchaudio==0.13.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 26)) (0.13.1)
# Requirement already satisfied: torchvision==0.14.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 27)) (0.14.1)
# Requirement already satisfied: tqdm==4.65.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 28)) (4.65.0)
# Requirement already satisfied: transformers==4.29.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 29)) (4.29.2)
# Requirement already satisfied: omegaconf==2.3.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 30)) (2.3.0)
# Requirement already satisfied: tensorboard==2.13.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (2.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.19.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (14.0.2)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (0.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (3.9.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (0.23.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: hjson in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.3->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.3->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 4)) (1.11.1.1)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.3->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 4)) (9.0.0)
# Requirement already satisfied: pydantic<2.0.0 in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.3->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 4)) (1.10.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.17.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 5)) (3.15.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.17.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 5)) (8.0.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.1.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.111.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.3.2)
# Requirement already satisfied: gradio-client==0.5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.27.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (3.10.6)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.0.9)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.30.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (11.0.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath==0.1.10->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: ipython>=7.31.1 in /usr/local/lib/python3.10/dist-packages (from ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (7.34.0)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (4.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 13)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 13)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 13)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 13)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 13)) (2.8.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from mdtex2html==1.2.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 14)) (3.6)
# Requirement already satisfied: latex2mathml in /usr/local/lib/python3.10/dist-packages (from mdtex2html==1.2.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 14)) (3.77.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.2->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 17)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.2->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 17)) (2024.1)
# Requirement already satisfied: fvcore in /usr/local/lib/python3.10/dist-packages (from pytorchvideo==0.1.5->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 20)) (0.1.5.post20221221)
# Requirement already satisfied: av in /usr/local/lib/python3.10/dist-packages (from pytorchvideo==0.1.5->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 20)) (12.2.0)
# Requirement already satisfied: parameterized in /usr/local/lib/python3.10/dist-packages (from pytorchvideo==0.1.5->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 20)) (0.9.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pytorchvideo==0.1.5->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 20)) (3.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 24)) (0.4.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 25)) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 25)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 25)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 25)) (11.7.99)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.29.2->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 29)) (0.13.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf==2.3.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 30)) (4.9.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (1.0.0)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (3.0.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (0.43.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (0.19.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.1->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.12.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 2)) (2024.6.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 20)) (0.1.8)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 20)) (2.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 20)) (0.9.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.17.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 5)) (3.19.2)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.12.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.31.1->ipdb==0.13.13->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard==2.13.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 31)) (3.2.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (1.2.1)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.22.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.44.0->-r /content/drive/MyDrive/next-gpt/NExT-GPT-new/requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: data in /usr/local/lib/python3.10/dist-packages (0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from data) (1.16.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from data) (4.4.2)
# Requirement already satisfied: funcsigs in /usr/local/lib/python3.10/dist-packages (from data) (1.0.2)
# Collecting jax==0.4.8
#   Using cached jax-0.4.8-py3-none-any.whl
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.8) (0.2.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.8) (1.24.3)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax==0.4.8) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.8) (1.11.2)
# Installing collected packages: jax
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires jaxlib>=0.1.37, which is not installed.
# dopamine-rl 4.0.9 requires flax>=0.2.0, which is not installed.
# dopamine-rl 4.0.9 requires jaxlib>=0.1.51, which is not installed.
# optax 0.2.2 requires jaxlib>=0.1.37, which is not installed.
# orbax-checkpoint 0.4.4 requires jaxlib, which is not installed.
# chex 0.1.86 requires jax>=0.4.16, but you have jax 0.4.8 which is incompatible.
# orbax-checkpoint 0.4.4 requires jax>=0.4.9, but you have jax 0.4.8 which is incompatible.
# Successfully installed jax-0.4.8
# Requirement already satisfied: diffusers==0.17.0 in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.17.0) (9.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.17.0) (3.15.4)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.17.0) (0.23.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.17.0) (8.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.17.0) (1.24.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.17.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.17.0) (2.31.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.17.0) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.17.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.17.0) (6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.17.0) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.17.0) (4.12.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.17.0) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.17.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.17.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.17.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.17.0) (2024.6.2)
# Found existing installation: jax 0.4.8
# Uninstalling jax-0.4.8:
#   Successfully uninstalled jax-0.4.8
# WARNING: Skipping jaxlib as it is not installed.
# WARNING: Skipping flax as it is not installed.
# Collecting jax==0.3.25
#   Using cached jax-0.3.25.tar.gz (1.1 MB)
#   Preparing metadata (setup.py) ... done
# ERROR: Could not find a version that satisfies the requirement jaxlib==0.3.25 (from versions: 0.4.6, 0.4.7, 0.4.9, 0.4.10, 0.4.11, 0.4.12, 0.4.13, 0.4.14, 0.4.16, 0.4.17, 0.4.18, 0.4.19, 0.4.20, 0.4.21, 0.4.22, 0.4.23, 0.4.24, 0.4.25, 0.4.26, 0.4.27, 0.4.28, 0.4.29, 0.4.30)
# ERROR: No matching distribution found for jaxlib==0.3.25
# Found existing installation: matplotlib 3.7.1
# Uninstalling matplotlib-3.7.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/matplotlib-3.7.1-py3.10-nspkg.pth
#     /usr/local/lib/python3.10/dist-packages/matplotlib-3.7.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/matplotlib/*
#     /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axes_grid1/*
#     /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axisartist/*
#     /usr/local/lib/python3.10/dist-packages/mpl_toolkits/mplot3d/*
#     /usr/local/lib/python3.10/dist-packages/pylab.py
# Proceed (Y/n)? Y
# Y
#   Successfully uninstalled matplotlib-3.7.1
# Found existing installation: Pillow 9.5.0
# Uninstalling Pillow-9.5.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/PIL/*
#     /usr/local/lib/python3.10/dist-packages/Pillow-9.5.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libXau-154567c4.so.6.0.0
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libbrotlicommon-92722cb2.so.1
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libbrotlidec-db4b3db6.so.1.0.9
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libfreetype-cb9caf6f.so.6.19.0
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libharfbuzz-3543f599.so.0.60710.0
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libjpeg-f2134fdd.so.62.3.0
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/liblcms2-12745711.so.2.0.15
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/liblzma-95592ee6.so.5.4.2
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libopenjp2-78c47f58.so.2.5.0
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libpng16-cb42a3c6.so.16.39.0
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libsharpyuv-9340467d.so.0.0.0
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libtiff-b9364ff1.so.6.0.0
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libwebp-3ee34a0b.so.7.1.6
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libwebpdemux-785dd7eb.so.2.0.12
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libwebpmux-ddfacf1d.so.3.0.11
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libxcb-3e83370d.so.1.1.0
# Proceed (Y/n)? Y
#   Successfully uninstalled Pillow-9.5.0
# Y
# Found existing installation: numpy 1.24.3
# Uninstalling numpy-1.24.3:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/f2py3
#     /usr/local/bin/f2py3.10
#     /usr/local/lib/python3.10/dist-packages/numpy-1.24.3.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libgfortran-040039e1.so.5.0.0
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libopenblas64_p-r0-15028c96.3.21.so
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.10/dist-packages/numpy/*
# Proceed (Y/n)?   Successfully uninstalled numpy-1.24.3
# Collecting matplotlib
#   Using cached matplotlib-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Collecting numpy>=1.23 (from matplotlib)
#   Using cached numpy-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, numpy, matplotlib
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires jax>=0.4.16, which is not installed.
# chex 0.1.86 requires jaxlib>=0.1.37, which is not installed.
# dopamine-rl 4.0.9 requires flax>=0.2.0, which is not installed.
# dopamine-rl 4.0.9 requires jax>=0.1.72, which is not installed.
# dopamine-rl 4.0.9 requires jaxlib>=0.1.51, which is not installed.
# optax 0.2.2 requires jax>=0.1.55, which is not installed.
# optax 0.2.2 requires jaxlib>=0.1.37, which is not installed.
# orbax-checkpoint 0.4.4 requires jax>=0.4.9, which is not installed.
# orbax-checkpoint 0.4.4 requires jaxlib, which is not installed.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.0.0 which is incompatible.
# cudf-cu12 24.4.1 requires numpy<2.0a0,>=1.23, but you have numpy 2.0.0 which is incompatible.
# cupy-cuda12x 12.2.0 requires numpy<1.27,>=1.20, but you have numpy 2.0.0 which is incompatible.
# gradio 3.44.0 requires numpy~=1.0, but you have numpy 2.0.0 which is incompatible.
# ibis-framework 8.0.0 requires numpy<2,>=1, but you have numpy 2.0.0 which is incompatible.
# numba 0.58.1 requires numpy<1.27,>=1.22, but you have numpy 2.0.0 which is incompatible.
# rmm-cu12 24.4.0 requires numpy<2.0a0,>=1.23, but you have numpy 2.0.0 which is incompatible.
# scipy 1.11.2 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.0.0 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 2.0.0 which is incompatible.
# tensorflow 2.15.0 requires tensorboard<2.16,>=2.15, but you have tensorboard 2.13.0 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.0.0 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed matplotlib-3.9.1 numpy-2.0.0 pillow-10.4.0
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (10.4.0)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 242, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 441, in run
#     conflicts = self._determine_conflicts(to_install)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 572, in _determine_conflicts
#     return check_install_conflicts(to_install)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/operations/check.py", line 42, in create_package_set_from_installed
#     dependencies = list(dist.iter_dependencies())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/metadata/pkg_resources.py", line 216, in iter_dependencies
#     return self._dist.requires(extras)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2821, in requires
#     dm = self._dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3110, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3120, in _compute_dependencies
#     reqs.extend(parse_requirements(req))
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3173, in __init__
#     super(Requirement, self).__init__(requirement_string)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/packaging/requirements.py", line 102, in __init__
#     req = REQUIREMENT.parseString(requirement_string)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 1131, in parse_string
#     loc, tokens = self._parse(instring, 0)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 817, in _parseNoCache
#     loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 3864, in parseImpl
#     loc, resultlist = self.exprs[0]._parse(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 825, in _parseNoCache
#     ret_tokens = ParseResults(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/results.py", line 154, in __new__
#     self._tokdict = dict()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 79, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     return run(options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 206, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.10/logging/__init__.py", line 1524, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1622, in _log
#     record = self.makeRecord(self.name, level, fn, lno, msg, args,
#   File "/usr/lib/python3.10/logging/__init__.py", line 1591, in makeRecord
#     rv = _logRecordFactory(name, level, fn, lno, msg, args, exc_info, func,
#   File "/usr/lib/python3.10/logging/__init__.py", line 313, in __init__
#     self.levelname = getLevelName(level)
#   File "/usr/lib/python3.10/logging/__init__.py", line 138, in getLevelName
#     result = _levelToName.get(level)
# KeyboardInterrupt
# ^C
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (2.0.0)

# %%
# !pip install numpy==1.24.3
# Out:
# Collecting numpy==1.24.3
#   Using cached numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires jax>=0.4.16, which is not installed.
# chex 0.1.86 requires jaxlib>=0.1.37, which is not installed.
# dopamine-rl 4.0.9 requires flax>=0.2.0, which is not installed.
# dopamine-rl 4.0.9 requires jax>=0.1.72, which is not installed.
# dopamine-rl 4.0.9 requires jaxlib>=0.1.51, which is not installed.
# optax 0.2.2 requires jax>=0.1.55, which is not installed.
# optax 0.2.2 requires jaxlib>=0.1.37, which is not installed.
# orbax-checkpoint 0.4.4 requires jax>=0.4.9, which is not installed.
# orbax-checkpoint 0.4.4 requires jaxlib, which is not installed.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.3 which is incompatible.
# tensorflow 2.15.0 requires tensorboard<2.16,>=2.15, but you have tensorboard 2.13.0 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed numpy-1.24.3

# %%
# !pip install torch==1.13.1
# Out:
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (4.12.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1) (0.43.0)

# %%
# %cd /content/drive/MyDrive/next-gpt/NExT-GPT-new/code
# Out:
# /content/drive/MyDrive/next-gpt/NExT-GPT-new/code

# %%
import torch
from config import *

# %%
g_cuda = torch.Generator(device='cuda').manual_seed(1337)

args = {'model': 'nextgpt',
        'nextgpt_ckpt_path': '/content/drive/MyDrive/next-gpt/NExT-GPT-new/ckpt/delta_ckpt/nextgpt/7b_tiva_v0',
        'max_length': 128,
        'stage': 3,
        'root_dir': '/content/drive/MyDrive/next-gpt/NExT-GPT-new',
        'mode': 'validate',
        'pretrained_ckpt_path': '/content/drive/MyDrive/next-gpt/NExT-GPT-new/ckpt/pretrained_ckpt',
        }
args.update(load_config(args))
args['pretrained_ckpt_path']= '/content/drive/MyDrive/next-gpt/NExT-GPT-new/ckpt/pretrained_ckpt'
# Out:
# [!] load base configuration: config/base.yaml
# [!] load configuration from config/stage_3.yaml

# %%
from model.anyToImageVideoAudio import NextGPTModel

model = NextGPTModel(**args)
# Out:
# Setting ds_accelerator to cuda (auto detect)
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(
# /content/drive/MyDrive/next-gpt/NExT-GPT-new/code/model/custom_sd.py:28: FutureWarning: Importing `DiffusionPipeline` or `ImagePipelineOutput` from diffusers.pipeline_utils is deprecated. Please import from diffusers.pipelines.pipeline_utils instead.
#   from diffusers.pipeline_utils import DiffusionPipeline
# args max_length 512
# Initializing visual encoder from /content/drive/MyDrive/next-gpt/NExT-GPT-new/ckpt/pretrained_ckpt/imagebind_ckpt/huge ...
# Visual encoder initialized.
# Initializing language decoder from /content/drive/MyDrive/next-gpt/NExT-GPT-new/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0 ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Instruct tuning the LLaMa ...
# trainable params: 33554432 || all params: 6771978240 || trainable%: 0.49548936530546206
# Language decoder initialized.
# Initializing tokenizer from /content/drive/MyDrive/next-gpt/NExT-GPT-new/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0 ...
# Adding [IMG0] token to vocabulary.
# Before adding new token, tokenizer("[IMG0]") = {'input_ids': [518, 7833, 29954, 29900, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[IMG0]") = {'input_ids': [32002], 'attention_mask': [1]}
# Adding [IMG1] token to vocabulary.
# Before adding new token, tokenizer("[IMG1]") = {'input_ids': [518, 7833, 29954, 29896, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[IMG1]") = {'input_ids': [32003], 'attention_mask': [1]}
# Adding [IMG2] token to vocabulary.
# Before adding new token, tokenizer("[IMG2]") = {'input_ids': [518, 7833, 29954, 29906, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[IMG2]") = {'input_ids': [32004], 'attention_mask': [1]}
# Adding [IMG3] token to vocabulary.
# Before adding new token, tokenizer("[IMG3]") = {'input_ids': [518, 7833, 29954, 29941, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[IMG3]") = {'input_ids': [32005], 'attention_mask': [1]}
# Adding [VID0] token to vocabulary.
# Before adding new token, tokenizer("[VID0]") = {'input_ids': [518, 13044, 29900, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID0]") = {'input_ids': [32006], 'attention_mask': [1]}
# Adding [VID1] token to vocabulary.
# Before adding new token, tokenizer("[VID1]") = {'input_ids': [518, 13044, 29896, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID1]") = {'input_ids': [32007], 'attention_mask': [1]}
# Adding [VID2] token to vocabulary.
# Before adding new token, tokenizer("[VID2]") = {'input_ids': [518, 13044, 29906, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID2]") = {'input_ids': [32008], 'attention_mask': [1]}
# Adding [VID3] token to vocabulary.
# Before adding new token, tokenizer("[VID3]") = {'input_ids': [518, 13044, 29941, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID3]") = {'input_ids': [32009], 'attention_mask': [1]}
# Adding [VID4] token to vocabulary.
# Before adding new token, tokenizer("[VID4]") = {'input_ids': [518, 13044, 29946, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID4]") = {'input_ids': [32010], 'attention_mask': [1]}
# Adding [VID5] token to vocabulary.
# Before adding new token, tokenizer("[VID5]") = {'input_ids': [518, 13044, 29945, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID5]") = {'input_ids': [32011], 'attention_mask': [1]}
# Adding [VID6] token to vocabulary.
# Before adding new token, tokenizer("[VID6]") = {'input_ids': [518, 13044, 29953, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID6]") = {'input_ids': [32012], 'attention_mask': [1]}
# Adding [VID7] token to vocabulary.
# Before adding new token, tokenizer("[VID7]") = {'input_ids': [518, 13044, 29955, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID7]") = {'input_ids': [32013], 'attention_mask': [1]}
# Adding [VID8] token to vocabulary.
# Before adding new token, tokenizer("[VID8]") = {'input_ids': [518, 13044, 29947, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID8]") = {'input_ids': [32014], 'attention_mask': [1]}
# Adding [VID9] token to vocabulary.
# Before adding new token, tokenizer("[VID9]") = {'input_ids': [518, 13044, 29929, 29962], 'attention_mask': [1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID9]") = {'input_ids': [32015], 'attention_mask': [1]}
# Adding [VID10] token to vocabulary.
# Before adding new token, tokenizer("[VID10]") = {'input_ids': [518, 13044, 29896, 29900, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID10]") = {'input_ids': [32016], 'attention_mask': [1]}
# Adding [VID11] token to vocabulary.
# Before adding new token, tokenizer("[VID11]") = {'input_ids': [518, 13044, 29896, 29896, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID11]") = {'input_ids': [32017], 'attention_mask': [1]}
# Adding [VID12] token to vocabulary.
# Before adding new token, tokenizer("[VID12]") = {'input_ids': [518, 13044, 29896, 29906, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID12]") = {'input_ids': [32018], 'attention_mask': [1]}
# Adding [VID13] token to vocabulary.
# Before adding new token, tokenizer("[VID13]") = {'input_ids': [518, 13044, 29896, 29941, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID13]") = {'input_ids': [32019], 'attention_mask': [1]}
# Adding [VID14] token to vocabulary.
# Before adding new token, tokenizer("[VID14]") = {'input_ids': [518, 13044, 29896, 29946, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID14]") = {'input_ids': [32020], 'attention_mask': [1]}
# Adding [VID15] token to vocabulary.
# Before adding new token, tokenizer("[VID15]") = {'input_ids': [518, 13044, 29896, 29945, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID15]") = {'input_ids': [32021], 'attention_mask': [1]}
# Adding [VID16] token to vocabulary.
# Before adding new token, tokenizer("[VID16]") = {'input_ids': [518, 13044, 29896, 29953, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID16]") = {'input_ids': [32022], 'attention_mask': [1]}
# Adding [VID17] token to vocabulary.
# Before adding new token, tokenizer("[VID17]") = {'input_ids': [518, 13044, 29896, 29955, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID17]") = {'input_ids': [32023], 'attention_mask': [1]}
# Adding [VID18] token to vocabulary.
# Before adding new token, tokenizer("[VID18]") = {'input_ids': [518, 13044, 29896, 29947, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID18]") = {'input_ids': [32024], 'attention_mask': [1]}
# Adding [VID19] token to vocabulary.
# Before adding new token, tokenizer("[VID19]") = {'input_ids': [518, 13044, 29896, 29929, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID19]") = {'input_ids': [32025], 'attention_mask': [1]}
# Adding [VID20] token to vocabulary.
# Before adding new token, tokenizer("[VID20]") = {'input_ids': [518, 13044, 29906, 29900, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID20]") = {'input_ids': [32026], 'attention_mask': [1]}
# Adding [VID21] token to vocabulary.
# Before adding new token, tokenizer("[VID21]") = {'input_ids': [518, 13044, 29906, 29896, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID21]") = {'input_ids': [32027], 'attention_mask': [1]}
# Adding [VID22] token to vocabulary.
# Before adding new token, tokenizer("[VID22]") = {'input_ids': [518, 13044, 29906, 29906, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID22]") = {'input_ids': [32028], 'attention_mask': [1]}
# Adding [VID23] token to vocabulary.
# Before adding new token, tokenizer("[VID23]") = {'input_ids': [518, 13044, 29906, 29941, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[VID23]") = {'input_ids': [32029], 'attention_mask': [1]}
# Adding [AUD0] token to vocabulary.
# Before adding new token, tokenizer("[AUD0]") = {'input_ids': [518, 29909, 15789, 29900, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[AUD0]") = {'input_ids': [32030], 'attention_mask': [1]}
# Adding [AUD1] token to vocabulary.
# Before adding new token, tokenizer("[AUD1]") = {'input_ids': [518, 29909, 15789, 29896, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[AUD1]") = {'input_ids': [32031], 'attention_mask': [1]}
# Adding [AUD2] token to vocabulary.
# Before adding new token, tokenizer("[AUD2]") = {'input_ids': [518, 29909, 15789, 29906, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[AUD2]") = {'input_ids': [32032], 'attention_mask': [1]}
# Adding [AUD3] token to vocabulary.
# Before adding new token, tokenizer("[AUD3]") = {'input_ids': [518, 29909, 15789, 29941, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[AUD3]") = {'input_ids': [32033], 'attention_mask': [1]}
# Adding [AUD4] token to vocabulary.
# Before adding new token, tokenizer("[AUD4]") = {'input_ids': [518, 29909, 15789, 29946, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[AUD4]") = {'input_ids': [32034], 'attention_mask': [1]}
# Adding [AUD5] token to vocabulary.
# Before adding new token, tokenizer("[AUD5]") = {'input_ids': [518, 29909, 15789, 29945, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[AUD5]") = {'input_ids': [32035], 'attention_mask': [1]}
# Adding [AUD6] token to vocabulary.
# Before adding new token, tokenizer("[AUD6]") = {'input_ids': [518, 29909, 15789, 29953, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[AUD6]") = {'input_ids': [32036], 'attention_mask': [1]}
# Adding [AUD7] token to vocabulary.
# Before adding new token, tokenizer("[AUD7]") = {'input_ids': [518, 29909, 15789, 29955, 29962], 'attention_mask': [1, 1, 1, 1, 1]}
# After adding 1 new tokens, tokenizer("[AUD7]") = {'input_ids': [32037], 'attention_mask': [1]}
# Tokenizer initialized.

# %%
import os

delta_ckpt = torch.load(os.path.join(args['nextgpt_ckpt_path'], 'pytorch_model.pt'), map_location=torch.device('cuda'))
model.load_state_dict(delta_ckpt, strict=False)
model = model.eval().half().cuda()

# %%
def predict(
    input,
    image_path=None,
    audio_path=None,
    video_path=None,
    thermal_path=None,
    max_tgt_len=200,
    top_p=10.0,
    temperature=0.1,
    history=None,
    modality_cache=None,
    filter_value=-float('Inf'), min_word_tokens=0,
    gen_scale_factor=10.0, max_num_imgs=1,
    stops_id=None,
    load_sd=True,
    generator=None,
    guidance_scale_for_img=7.5,
    num_inference_steps_for_img=50,
    guidance_scale_for_vid=7.5,
    num_inference_steps_for_vid=50,
    max_num_vids=1,
    height=320,
    width=576,
    num_frames=24,
    guidance_scale_for_aud=7.5,
    num_inference_steps_for_aud=50,
    max_num_auds=1,
    audio_length_in_s=9,
    ENCOUNTERS=1,
):
    if image_path is None and audio_path is None and video_path is None and thermal_path is None:
        # return [(input, "There is no input data provided! Please upload your data and start the conversation.")]
        print('no image, audio, video, and thermal are input')
    else:
        print(
            f'[!] image path: {image_path}\n[!] audio path: {audio_path}\n[!] video path: {video_path}\n[!] thermal path: {thermal_path}')

    # prepare the prompt
    prompt_text = ''
    if history != None:
        for idx, (q, a) in enumerate(history):
            if idx == 0:
                prompt_text += f'{q}\n### Assistant: {a}\n###'
            else:
                prompt_text += f' Human: {q}\n### Assistant: {a}\n###'
        prompt_text += f'### Human: {input}'
    else:
        prompt_text += f'### Human: {input}'

    print('prompt_text: ', prompt_text)

    response = model.generate({
        'prompt': prompt_text,
        'image_paths': [image_path] if image_path else [],
        'audio_paths': [audio_path] if audio_path else [],
        'video_paths': [video_path] if video_path else [],
        'thermal_paths': [thermal_path] if thermal_path else [],
        'top_p': top_p,
        'temperature': temperature,
        'max_tgt_len': max_tgt_len,
        'modality_embeds': modality_cache,
        'filter_value': filter_value, 'min_word_tokens': min_word_tokens,
        'gen_scale_factor': gen_scale_factor, 'max_num_imgs': max_num_imgs,
        'stops_id': stops_id,
        'load_sd': load_sd,
        'generator': generator,
        'guidance_scale_for_img': guidance_scale_for_img,
        'num_inference_steps_for_img': num_inference_steps_for_img,

        'guidance_scale_for_vid': guidance_scale_for_vid,
        'num_inference_steps_for_vid': num_inference_steps_for_vid,
        'max_num_vids': max_num_vids,
        'height': height,
        'width': width,
        'num_frames': num_frames,

        'guidance_scale_for_aud': guidance_scale_for_aud,
        'num_inference_steps_for_aud': num_inference_steps_for_aud,
        'max_num_auds': max_num_auds,
        'audio_length_in_s': audio_length_in_s,
        'ENCOUNTERS': ENCOUNTERS,

    })
    return response

# %%
max_tgt_length = 150
top_p = 1.0
temperature = 0.4
modality_cache = None

prompt = 'Generate a image : woman walk a dop in the park.'

history = []

output = predict(
    input=prompt,
    history=history,
    max_tgt_len=max_tgt_length, top_p=top_p,
    temperature=temperature, modality_cache=modality_cache,
    filter_value=-float('Inf'), min_word_tokens=10,
    gen_scale_factor=4.0, max_num_imgs=1,
    stops_id=[[835]],
    load_sd=True,
    generator=g_cuda,
    guidance_scale_for_img=7.5,
    num_inference_steps_for_img=50,
    guidance_scale_for_vid=7.5,
    num_inference_steps_for_vid=50,
    max_num_vids=1,
    height=320,
    width=576,
    num_frames=24,
    ENCOUNTERS=1
    )
# Out:
# no image, audio, video, and thermal are input
# prompt_text:  ### Human: Generate a image : woman walk a dop in the park.
# text prompt:  ### Human: Generate a image : woman walk a dop in the park.
# ### Assistant:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1255: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# all_gen_img_idx:  []
# all_gen_vid_idx:  []
# all_gen_aud_idx:  []

# %%
from diffusers.utils import export_to_video
import scipy

for i in output:
    if isinstance(i, str):
        print(i)
    elif 'img' in i.keys():
        for m in i['img']:
            if isinstance(m, str):
                print(m)
            else:
                m[0].save(f'./results/{prompt}.jpg')

    elif 'vid' in i.keys():
        for idx, m in enumerate(i['vid']):
            if isinstance(m, str):
                print(m)
            else:
                video_path = export_to_video(video_frames=m, output_video_path=f'./results/{prompt}.mp4')
                print("video_path: ", video_path)
    elif 'aud' in i.keys():
        for idx, m in enumerate(i['aud']):
            if isinstance(m, str):
                print(m)
            else:
                audio_path = f'./results/{prompt}.wav'
                scipy.io.wavfile.write(audio_path, rate=16000, data=m)
                print("video_path: ", audio_path)
    else:
        pass
# Out:
# I'm sorry, but as an AI language model, I don't have the capability to generate images. However, I can suggest some ideas for the image:
#
# 1. The woman is walking in a park with beautiful green grass and colorful flowers in the background.
# 2. She is wearing comfortable and stylish clothing, and has a big smile on her face, enjoying the peaceful ambiance of the park.
# 3. The park is surrounded by tall trees, and the woman is surrounded by nature's beauty.
# 4. The sun is setting, casting a warm glow on the scene, as the woman walks gracefully through the park.
# 5. The image could also

# %%
import torch
import os
import tempfile
from PIL import Image
import scipy
import imageio
import yaml
import re
from model.anyToImageVideoAudio import NextGPTModel

def load_model_config(stage, mode):
    # load special config for each model
    config_path = f'config/stage_{stage}.yaml'
    print(f'[!] load configuration from {config_path}')
    with open(config_path) as f:
        configuration = yaml.load(f, Loader=yaml.FullLoader)
        new_config = {}
        for key, value in configuration.items():
            if key in ['train', 'test', 'validation']:
                if mode == key:
                    new_config.update(value)
            else:
                new_config[key] = value
        configuration = new_config
    return configuration

def load_base_config():
    config_path = f'config/base.yaml'
    with open(config_path) as f:
        configuration = yaml.load(f, Loader=yaml.FullLoader)
    print(f'[!] load base configuration: {config_path}')
    return configuration

def load_config(args):
    '''the configuration of each model can rewrite the base configuration'''
    # base config
    base_configuration = load_base_config()

    # load stage config
    stage_configuration = load_model_config(args['stage'], args.get('mode', 'default'))

    # update and append the stage config for base config
    base_configuration.update(stage_configuration)
    configuration = base_configuration
    return configuration

def save_image_to_local(image: Image.Image):
    if not os.path.exists('temp'):
        os.mkdir('temp')
    filename = os.path.join('temp', next(tempfile._get_candidate_names()) + '.jpg')
    image.save(filename)
    return filename

def save_video_to_local(video):
    if not os.path.exists('temp'):
        os.mkdir('temp')
    filename = os.path.join('temp', next(tempfile._get_candidate_names()) + '.mp4')
    writer = imageio.get_writer(filename, format='FFMPEG', fps=8)
    for frame in video:
        writer.append_data(frame)
    writer.close()
    return filename

def save_audio_to_local(audio):
    if not os.path.exists('temp'):
        os.mkdir('temp')
    filename = os.path.join('temp', next(tempfile._get_candidate_names()) + '.wav')
    scipy.io.wavfile.write(filename, rate=16000, data=audio)
    return filename

def parse_text(text, image_path, video_path, audio_path):
    outputs = text
    lines = text.split("\n")
    lines = [line for line in lines if line != ""]
    count = 0
    for i, line in enumerate(lines):
        if "```" in line:
            count += 1
            items = line.split('`')
            if count % 2 == 1:
                lines[i] = f'<pre><code class="language-{items[-1]}">'
            else:
                lines[i] = f'<br></code></pre>'
        else:
            if i > 0:
                if count % 2 == 1:
                    line = line.replace("`", "\`")
                    line = line.replace("<", "&lt;")
                    line = line.replace(">", "&gt;")
                    line = line.replace(" ", "&nbsp;")
                    line = line.replace("*", "&ast;")
                    line = line.replace("_", "&lowbar;")
                    line = line.replace("-", "&#45;")
                    line = line.replace(".", "&#46;")
                    line = line.replace("!", "&#33;")
                    line = line.replace("(", "&#40;")
                    line = line.replace(")", "&#41;")
                    line = line.replace("$", "&#36;")
                lines[i] = "<br>" + line
    text = "".join(lines) + "<br>"
    res_text = ''
    split_text = re.split(r' <|> ', text)
    image_path_list, video_path_list, audio_path_list = [], [], []
    for st in split_text:
        if st.startswith('<Image>'):
            pattern = r'Image>(.*?)<\/Image'
            matches = re.findall(pattern, text)
            for m in matches:
                image_path_list.append(m)
        elif st.startswith('<Audio>'):
            pattern = r'Audio>(.*?)<\/Audio'
            matches = re.findall(pattern, text)
            for m in matches:
                audio_path_list.append(m)
        elif st.startswith('<Video>'):
            pattern = r'Video>(.*?)<\/Video'
            matches = re.findall(pattern, text)
            for m in matches:
                video_path_list.append(m)
        else:
            res_text += st
    text = res_text
    if image_path is not None:
        text += f'<img src="./file={image_path}" style="display: inline-block;width: 250px;max-height: 400px;"><br>'
        outputs = f'<Image>{image_path}</Image> ' + outputs
    if len(image_path_list) > 0:
        for i in image_path_list:
            text += f'<img src="./file={i}" style="display: inline-block;width: 250px;max-height: 400px;"><br>'
            outputs = f'<Image>{i}</Image> ' + outputs
    if video_path is not None:
        text += f' <video controls playsinline width="500" style="display: inline-block;"  src="./file={video_path}"></video><br>'
        outputs = f'<Video>{video_path}</Video> ' + outputs
    if audio_path is not None:
        text += f'<audio controls playsinline><source src="./file={audio_path}" type="audio/wav"></audio><br>'
        outputs = f'<Audio>{audio_path}</Audio> ' + outputs
    if len(audio_path_list) > 0:
        for i in audio_path_list:
            text += f'<audio controls playsinline><source src="./file={i}" type="audio/wav"></audio><br>'
            outputs = f'<Audio>{i}</Audio> ' + outputs
    text = text[:-len("<br>")].rstrip() if text.endswith("<br>") else text
    return text, outputs

def parse_response(model_outputs):
    response = ''
    text_outputs = []
    for output_i, p in enumerate(model_outputs):
        if isinstance(p, str):
            response += p
            response += '<br>'
            text_outputs.append(p)
        elif 'img' in p.keys():
            _temp_output = ''
            for m in p['img']:
                if isinstance(m, str):
                    response += m.replace(' '.join([f'[IMG{i}]' for i in range(args['num_gen_img_tokens'])]), '')
                    response += '<br>'
                    _temp_output += m.replace(' '.join([f'[IMG{i}]' for i in range(args['num_gen_img_tokens'])]), '')
                else:
                    filename = save_image_to_local(m[0])
                    print(filename)
                    _temp_output = f'<Image>{filename}</Image> ' + _temp_output
                    response += f'<img src="./file={filename}" style="display: inline-block;width: 250px;max-height: 400px;">'
            text_outputs.append(_temp_output)
        elif 'vid' in p.keys():
            _temp_output = ''
            for idx, m in enumerate(p['vid']):
                if isinstance(m, str):
                    response += m.replace(' '.join([f'[VID{i}]' for i in range(args['num_gen_video_tokens'])]), '')
                    response += '<br>'
                    _temp_output += m.replace(' '.join([f'[VID{i}]' for i in range(args['num_gen_video_tokens'])]), '')
                else:
                    filename = save_video_to_local(m)
                    print(filename)
                    _temp_output = f'<Video>{filename}</Video> ' + _temp_output
                    response += f'<video controls playsinline width="500" style="display: inline-block;"  src="./file={filename}"></video>'
            text_outputs.append(_temp_output)
        elif 'aud' in p.keys():
            _temp_output = ''
            for idx, m in enumerate(p['aud']):
                if isinstance(m, str):
                    response += m.replace(' '.join([f'[AUD{i}]' for i in range(args['num_gen_audio_tokens'])]), '')
                    response += '<br>'
                    _temp_output += m.replace(' '.join([f'[AUD{i}]' for i in range(args['num_gen_audio_tokens'])]), '')
                else:
                    filename = save_audio_to_local(m)
                    print(filename)
                    _temp_output = f'<Audio>{filename}</Audio> ' + _temp_output
                    response += f'<audio controls playsinline><source src="./file={filename}" type="audio/wav"></audio>'
            text_outputs.append(_temp_output)
        else:
            pass
    response = response[:-len("<br>")].rstrip() if response.endswith("<br>") else response
    return response, text_outputs

def predict(
        prompt_input,
        image_path=None,
        audio_path=None,
        video_path=None,
        history=None,
        top_p=1.0,
        temperature=0.4,
        guidance_scale_for_img=7.5,
        num_inference_steps_for_img=50,
        guidance_scale_for_vid=7.5,
        num_inference_steps_for_vid=50,
        num_frames=24,
        guidance_scale_for_aud=7.5,
        num_inference_steps_for_aud=50,
        audio_length_in_s=9,
        max_length=246,
        filter_value=-float('Inf'),
        min_word_tokens=10,
        gen_scale_factor=4.0,
        max_num_imgs=1,
        stops_id=[[835]],
        load_sd=True,
        generator=None,
        ENCOUNTERS=1,
        height=320,
        width=576,
        max_num_vids=1,
        max_num_auds=1
):
    # prepare the prompt
    prompt_text = ''

    if len(history) == 0:
        prompt_text += '### Human: '
        if image_path is not None:
            prompt_text += f'<Image>{image_path}</Image> '
        if audio_path is not None:
            prompt_text += f'<Audio>{audio_path}</Audio> '
        if video_path is not None:
            prompt_text += f'<Video>{video_path}</Video> '
        prompt_text += f' {prompt_input}'
    else:
        for idx, (q, a) in enumerate(history):
            if idx == 0:
                prompt_text += f'### Human: {q}\n### Assistant: {a}\n###'
            else:
                prompt_text += f' Human: {q}\n### Assistant: {a}\n###'
        prompt_text += ' Human: '
        if image_path is not None:
            prompt_text += f'<Image>{image_path}</Image> '
        if audio_path is not None:
            prompt_text += f'<Audio>{audio_path}</Audio> '
        if video_path is not None:
            prompt_text += f'<Video>{video_path}</Video> '
        prompt_text += f' {prompt_input}'
    print('prompt_text: ', prompt_text)
    print('image_path: ', image_path)
    print('audio_path: ', audio_path)
    print('video_path: ', video_path)
    response = model.generate({
        'prompt': prompt_text,
        'image_paths': [image_path] if image_path else [],
        'audio_paths': [audio_path] if audio_path else [],
        'video_paths': [video_path] if video_path else [],
        'top_p': top_p,
        'temperature': temperature,
        'max_tgt_len': max_length,
        'filter_value': filter_value, 'min_word_tokens': min_word_tokens,
        'gen_scale_factor': gen_scale_factor, 'max_num_imgs': max_num_imgs,
        'stops_id': stops_id,
        'load_sd': load_sd,
        'generator': generator,
        'guidance_scale_for_img': guidance_scale_for_img,
        'num_inference_steps_for_img': num_inference_steps_for_img,
        'guidance_scale_for_vid': guidance_scale_for_vid,
        'num_inference_steps_for_vid': num_inference_steps_for_vid,
        'max_num_vids': max_num_vids,
        'height': height,
        'width': width,
        'num_frames': num_frames,
        'guidance_scale_for_aud': guidance_scale_for_aud,
        'num_inference_steps_for_aud': num_inference_steps_for_aud,
        'max_num_auds': max_num_auds,
        'audio_length_in_s': audio_length_in_s,
        'ENCOUNTERS': ENCOUNTERS,
    })
    response_chat, response_outputs = parse_response(response)
    print('text_outputs: ', response_outputs)
    user_chat, user_outputs = parse_text(prompt_input, image_path, video_path, audio_path)
    history.append((user_outputs, ''.join(response_outputs).replace('\n###', '')))
    return response_chat, history

# # init the model
# g_cuda = torch.Generator(device='cuda').manual_seed(1337)
# args = {'model': 'nextgpt',
#         'nextgpt_ckpt_path': '../ckpt/delta_ckpt/nextgpt/7b_tiva_v0/',
#         'max_length': 128,
#         'stage': 3,
#         'root_dir': '../',
#         'mode': 'validate',
#         }
# args.update(load_config(args))

# model = NextGPTModel(**args)
# delta_ckpt = torch.load(os.path.join(args['nextgpt_ckpt_path'], 'pytorch_model.pt'), map_location=torch.device('cuda'))
# model.load_state_dict(delta_ckpt, strict=False)
# model = model.eval().half().cuda()
# print(f'[!] init the 7b model over ...')

prompt = 'show me a video of a woman walking a dog in the park.'

history = []

response, updated_history = predict(prompt_input=prompt, history=history)
print("Response:", response)
print("Updated History:", updated_history)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-6fc1124da7ea> in <cell line: 1>()
# ----> 1 import torch
#       2 import os
#       3 import tempfile
#       4 from PIL import Image
#       5 import scipy
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#     893 import torch.backends.openmp
#     894 import torch.backends.quantized
# --> 895 import torch.utils.data
#     896 from torch import __config__ as __config__
#     897 from torch import __future__ as __future__
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/__init__.py in <module>
#      18     random_split,
#      19 )
# ---> 20 from torch.utils.data.datapipes.datapipe import (
#      21     DFIterDataPipe,
#      22     DataChunk,
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/datapipes/__init__.py in <module>
# ----> 1 from . import iter
#       2 from . import map
#       3 from . import dataframe
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/datapipes/iter/__init__.py in <module>
# ----> 1 from torch.utils.data.datapipes.iter.utils import (
#       2     IterableWrapperIterDataPipe as IterableWrapper,
#       3 )
#       4 from torch.utils.data.datapipes.iter.callable import (
#       5     CollatorIterDataPipe as Collator,
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/datapipes/iter/utils.py in <module>
#       1 import copy
#       2 import warnings
# ----> 3 from torch.utils.data.datapipes.datapipe import IterDataPipe
#       4
#       5 __all__ = ["IterableWrapperIterDataPipe", ]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/datapipes/datapipe.py in <module>
#       5 from torch.utils.data.datapipes._typing import _DataPipeMeta, _IterDataPipeMeta
#       6 from torch.utils.data.datapipes._hook_iterator import _SnapshotState
# ----> 7 from torch.utils.data.datapipes.utils.common import (
#       8     _deprecation_warning,
#       9     _iter_deprecated_functional_names,
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/datapipes/utils/common.py in <module>
#      10
#      11
# ---> 12 from torch.utils.data._utils.serialization import DILL_AVAILABLE
#      13
#      14 __all__ = [
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/serialization.py in <module>
#       1 try:
# ----> 2     import dill
#       3
#       4     # XXX: By default, dill writes the Pickler dispatch table to inject its
#       5     # own logic there. This globally affects the behavior of the standard library
#
# /usr/local/lib/python3.10/dist-packages/dill/__init__.py in <module>
#      24
#      25
# ---> 26 from ._dill import (
#      27     Pickler, Unpickler,
#      28     check, copy, dump, dumps, load, loads, pickle, pickles, register,
#
# /usr/local/lib/python3.10/dist-packages/dill/_dill.py in <module>
#     148 try:
#     149     from _pyio import open as _open
# --> 150     PyTextWrapperType = get_file_type('r', buffering=-1, open=_open)
#     151     PyBufferedRandomType = get_file_type('r+b', buffering=-1, open=_open)
#     152     PyBufferedReaderType = get_file_type('rb', buffering=-1, open=_open)
#
# /usr/local/lib/python3.10/dist-packages/dill/_dill.py in get_file_type(*args, **kwargs)
#     136 def get_file_type(*args, **kwargs):
#     137     open = kwargs.pop("open", __builtin__.open)
# --> 138     f = open(os.devnull, *args, **kwargs)
#     139     t = type(f)
#     140     f.close()
#
# /usr/lib/python3.10/_pyio.py in open(file, mode, buffering, encoding, errors, newline, closefd, opener)
#     280             return result
#     281         encoding = text_encoding(encoding)
# --> 282         text = TextIOWrapper(buffer, encoding, errors, newline, line_buffering)
#     283         result = text
#     284         text.mode = mode
#
# /usr/lib/python3.10/_pyio.py in __init__(self, buffer, encoding, errors, newline, line_buffering, write_through)
#    2043                 encoding = "utf-8"
#    2044             else:
# -> 2045                 encoding = locale.getpreferredencoding(False)
#    2046
#    2047         if not isinstance(encoding, str):
#
# TypeError: <lambda>() takes 0 positional arguments but 1 was given

# %%
pip install --upgrade diffusers transformers torch
# Out:
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.29.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.15.4)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.23.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.24.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.4.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.82)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
pip install accelerate
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.19.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->accelerate) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)

# %%
import torch
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from diffusers.utils import export_to_video
from accelerate import init_empty_weights, infer_auto_device_map

# Load the pipeline with low_cpu_mem_usage=False and device_map using Accelerate
pipe = DiffusionPipeline.from_pretrained(
    "cerspense/zeroscope_v2_576w",
    torch_dtype=torch.float16,
    low_cpu_mem_usage=False
)

pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload()

prompt = "Darth Vader is surfing on waves"
video_frames = pipe(prompt, num_inference_steps=40, height=320, width=576, num_frames=24).frames
video_path = export_to_video(video_frames[0])

print(f"Video saved at {video_path}")
# Out:
# vae/diffusion_pytorch_model.safetensors not found
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--cerspense--zeroscope_v2_576w/snapshots/6963642a64dbefa93663d1ecebb4ceda2d9ecb28/unet: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--cerspense--zeroscope_v2_576w/snapshots/6963642a64dbefa93663d1ecebb4ceda2d9ecb28/unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--cerspense--zeroscope_v2_576w/snapshots/6963642a64dbefa93663d1ecebb4ceda2d9ecb28/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--cerspense--zeroscope_v2_576w/snapshots/6963642a64dbefa93663d1ecebb4ceda2d9ecb28/vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
#   0%|          | 0/40 [00:00<?, ?it/s]
# Video saved at /tmp/tmpc6ps6blq.mp4

# %%
# !zip -r /content/NExT-GPT.zip /content/NExT-GPT
# Out:
#   adding: content/NExT-GPT/ (stored 0%)
#   adding: content/NExT-GPT/.gitignore (stored 0%)
#   adding: content/NExT-GPT/data/ (stored 0%)
#   adding: content/NExT-GPT/data/T-X_pair_data/ (stored 0%)
#   adding: content/NExT-GPT/data/T-X_pair_data/webvid/ (stored 0%)
#   adding: content/NExT-GPT/data/T-X_pair_data/webvid/prepare.md (deflated 48%)
#   adding: content/NExT-GPT/data/T-X_pair_data/audiocap/ (stored 0%)
#   adding: content/NExT-GPT/data/T-X_pair_data/audiocap/prepare.md (deflated 56%)
#   adding: content/NExT-GPT/data/T-X_pair_data/cc3m/ (stored 0%)
#   adding: content/NExT-GPT/data/T-X_pair_data/cc3m/prepare.md (deflated 55%)
#   adding: content/NExT-GPT/data/IT_data/ (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/MosIT_data/ (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/MosIT_data/__init__.py (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T-T+X_data/ (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T-T+X_data/image_t2x.json (deflated 82%)
#   adding: content/NExT-GPT/data/IT_data/T-T+X_data/video_t2x.json (deflated 84%)
#   adding: content/NExT-GPT/data/IT_data/T-T+X_data/audio_t2x.json (deflated 84%)
#   adding: content/NExT-GPT/data/IT_data/T-T+X_data/__init__.py (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T+X-T_data/ (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T+X-T_data/alpaca/ (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T+X-T_data/alpaca/__init__.py (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T+X-T_data/videochat/ (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T+X-T_data/videochat/__init__.py (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T+X-T_data/llava/ (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T+X-T_data/llava/prapare.md (stored 0%)
#   adding: content/NExT-GPT/data/IT_data/T+X-T_data/__init__.py (stored 0%)
#   adding: content/NExT-GPT/figures/ (stored 0%)
#   adding: content/NExT-GPT/figures/framework.png (deflated 23%)
#   adding: content/NExT-GPT/figures/demo.png (deflated 1%)
#   adding: content/NExT-GPT/ckpt/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/special_tokens_map.json (deflated 72%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/pytorch_model.pt (deflated 9%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/added_tokens.json (deflated 74%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.gitattributes (deflated 87%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/tokenizer.model (deflated 55%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/config.json (deflated 43%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/HEAD (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/ea/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/ea/faac95fa1beba7525ed17bfc65e46ea3896cda (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/92/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/92/54bd04e5a156978c232d733ddc1e11faf09dc8 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/47/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/47/6975c77b59db40d7a9c83409f8d37f143ae950 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/pack/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/69/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/69/2bc700b5c589fd5dfa41a2baa0aa77ab2e5133 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/24/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/24/4d560dac2c2be3a825ad4f400735368a1fdea7 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/24/2de3174beb50d6db198205f034ff06f59be419 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/8c/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/8c/aa15f4fbbda3d15b0e620bb410cc07bfbe6895 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/ba/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/ba/fc03aa41189a072d6f2383281f63130b162ea0 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/6c/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/6c/00c742ce03c627d6cd5b795984876fa49fa899 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/6c/6fa9e8861a41dcfe39e503c762eea6757eecab (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/3f/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/3f/a43cc9049ad81d9a4e8b81801fe3465262834c (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/d4/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/d4/9bdd4642796101862c8f3ffafa789fa3821a1a (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/d5/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/d5/035ed512447f9246152a244469e153323c979d (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/44/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/44/e77a95384a9078687a1bffc0136c0179f218f6 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/1e/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/1e/1a9978a99207be181b1c1191efa32cec429a86 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/b2/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/b2/724f944c87007a0d17b96b00632d564bc45601 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/07/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/07/1102bca87f449970689523110f72844c89ee22 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/f2/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/f2/8bea33714c810ef6cb9b9e440edcddb93297a4 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/94/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/94/5da2d79b11bcc9698cbd9fb2c1105822d690d1 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/f4/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/f4/7cacd3419c121f7cbaedb8747ba9b5f13ef956 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/9a/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/9a/a8adeb8a33db3ee16ffc176f0e3a73caeda203 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/8e/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/8e/b29b0146258f0433846115d5c9ad7d749b7ff0 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/3c/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/3c/7c6a10d0d6f251612d9fbc86faab06d66fd918 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/a6/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/a6/344aac8c09253b3b630fb776ae94478aa0275b (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/info/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/74/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/74/2ef417622063d83f910ee8bd02024c0ecad810 (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/85/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/objects/85/4b4c9d3e396dfa3cd7f4c6f27ae0fd61d8593d (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/update.sample (deflated 68%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/pre-push (deflated 24%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/post-merge (deflated 25%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/post-commit (deflated 25%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/hooks/post-checkout (deflated 26%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/refs/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/refs/heads/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/refs/heads/main (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/refs/remotes/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/refs/tags/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/branches/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/config (deflated 37%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/index (deflated 36%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/tmp/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/objects/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/objects/8f/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/objects/8f/19/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/objects/8f/19/8f197e381254139cbb972aa37a219fd296b3ce80a45989073de8bd8c68a82327 (deflated 9%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/objects/9e/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/objects/9e/55/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/objects/9e/55/9e556afd44213b6bd1be2b850ebbbd98f5481437a8021afaf58ee7fb1818d347 (deflated 55%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/lfs/incomplete/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/info/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/info/exclude (deflated 28%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/description (deflated 14%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/packed-refs (deflated 10%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/logs/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/logs/HEAD (deflated 26%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/logs/refs/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/logs/refs/heads/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/logs/refs/heads/main (deflated 26%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/.git/logs/refs/remotes/origin/HEAD (deflated 26%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/tokenizer_config.json (deflated 68%)
#   adding: content/NExT-GPT/ckpt/delta_ckpt/nextgpt/7b_tiva_v0/README.md (deflated 43%)
#   adding: content/NExT-GPT/ckpt/__init__.py (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/huge/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/huge/imagebind_huge.pth (deflated 7%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/huge/__init__.py (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/huge/imagebind_huge.pth.1 (deflated 7%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/imagebind_ckpt/__init__.py (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/__init__.py (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/special_tokens_map.json (deflated 73%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/pytorch_model.bin.index.json (deflated 96%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.gitattributes (deflated 87%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/tokenizer.model (deflated 55%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/generation_config.json (deflated 28%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/config.json (deflated 42%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/HEAD (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/pack/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/48/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/48/972ca25fd39a8525072afc19ea7241a5a79cd1 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/6c/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/6c/00c742ce03c627d6cd5b795984876fa49fa899 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/5e/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/5e/fbbfd673521baf733d9cc2a6c018f127552e27 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/0a/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/0a/d52268b1a249e8a2d34cad3449a90d23c46f2b (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/72/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/72/60e497ec8b9bb7bd27c1cfe8ded8d75c1cdb28 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/32/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/32/0ba906b36adcaa104ec6f1a31d9500ad7274a7 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/f8/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/f8/7530efff7e7d67a5fe7bee2ba3acc023644def (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/d5/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/d5/16ee40a598cdfc869eb95d7d18e86af3beaf95 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/f5/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/f5/284e13914ffcf3f68ae7aaf0e705d51ebb456e (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/c7/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/c7/d9f3332a950355d5a77d85000f05e6f45435ea (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/5b/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/5b/dc763d2bbfec2c3158f171f0d55030f0099f45 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/c8/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/c8/81ac33f7dd7c892c8f29e900b7b675867fb062 (deflated 8%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/12/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/12/8b48946713166edcc3e3c62ae5fe285df776be (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/d8/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/d8/5ba6cb6820b01226ef8bd40b46bb489041c6a8 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/7f/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/7f/04f0e61ae5eebe2faca3f61c4c0169e8f551b5 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/f4/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/f4/75bc7ac91a7bb77ff2ae7b9613445c5ce655c1 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/b4/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/b4/a0e98235a6f553eabb99dab0366bbf6293278f (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/info/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/15/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/15/606dc6b7c9319c768c8f37417a41bd60c5b4d0 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/objects/15/4df8298fab5ecf322016157858e08cd1bccbe1 (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/update.sample (deflated 68%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/pre-push (deflated 24%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/post-merge (deflated 25%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/post-commit (deflated 25%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/hooks/post-checkout (deflated 26%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/refs/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/refs/heads/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/refs/heads/main (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/refs/remotes/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/refs/tags/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/branches/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/config (deflated 37%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/tmp/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/objects/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/objects/8f/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/objects/8f/37/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/objects/9e/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/objects/9e/55/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/objects/9e/55/9e556afd44213b6bd1be2b850ebbbd98f5481437a8021afaf58ee7fb1818d347 (deflated 55%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/objects/ef/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/objects/ef/1b/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/incomplete/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/incomplete/ef1b2c502e2eab32176400bd8af8636163619fb04e65c0c0fdea58f1cbe218073326542530 (deflated 8%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/lfs/incomplete/8f3789f864bf21ca0733d782022e3656759728151fab435e6799696124099a9a4292538491 (deflated 8%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/info/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/info/exclude (deflated 28%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/description (deflated 14%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/packed-refs (deflated 10%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/logs/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/logs/HEAD (deflated 28%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/logs/refs/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/logs/refs/heads/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/logs/refs/heads/main (deflated 28%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/.git/logs/refs/remotes/origin/HEAD (deflated 28%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/tokenizer_config.json (deflated 66%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/vicuna_ckpt/7b_v0/README.md (deflated 56%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/__init__.py (stored 0%)
#   adding: content/NExT-GPT/ckpt/pretrained_ckpt/prepare_vicuna.md (deflated 65%)
#   adding: content/NExT-GPT/.git/ (stored 0%)
#   adding: content/NExT-GPT/.git/HEAD (stored 0%)
#   adding: content/NExT-GPT/.git/objects/ (stored 0%)
#   adding: content/NExT-GPT/.git/objects/pack/ (stored 0%)
#   adding: content/NExT-GPT/.git/objects/pack/pack-ae5ee84ff429739905ae38639e6992bd088d473e.idx (deflated 3%)
#   adding: content/NExT-GPT/.git/objects/pack/pack-ae5ee84ff429739905ae38639e6992bd088d473e.pack (deflated 0%)
#   adding: content/NExT-GPT/.git/objects/info/ (stored 0%)
#   adding: content/NExT-GPT/.git/hooks/ (stored 0%)
#   adding: content/NExT-GPT/.git/hooks/update.sample (deflated 68%)
#   adding: content/NExT-GPT/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/NExT-GPT/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/NExT-GPT/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/NExT-GPT/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/NExT-GPT/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/NExT-GPT/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/NExT-GPT/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/NExT-GPT/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/NExT-GPT/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/NExT-GPT/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/NExT-GPT/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/NExT-GPT/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/NExT-GPT/.git/refs/ (stored 0%)
#   adding: content/NExT-GPT/.git/refs/heads/ (stored 0%)
#   adding: content/NExT-GPT/.git/refs/heads/main (stored 0%)
#   adding: content/NExT-GPT/.git/refs/remotes/ (stored 0%)
#   adding: content/NExT-GPT/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/NExT-GPT/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/NExT-GPT/.git/refs/tags/ (stored 0%)
#   adding: content/NExT-GPT/.git/branches/ (stored 0%)
#   adding: content/NExT-GPT/.git/config (deflated 33%)
#   adding: content/NExT-GPT/.git/index (deflated 57%)
#   adding: content/NExT-GPT/.git/info/ (stored 0%)
#   adding: content/NExT-GPT/.git/info/exclude (deflated 28%)
#   adding: content/NExT-GPT/.git/description (deflated 14%)
#   adding: content/NExT-GPT/.git/packed-refs (deflated 9%)
#   adding: content/NExT-GPT/.git/logs/ (stored 0%)
#   adding: content/NExT-GPT/.git/logs/HEAD (deflated 27%)
#   adding: content/NExT-GPT/.git/logs/refs/ (stored 0%)
#   adding: content/NExT-GPT/.git/logs/refs/heads/ (stored 0%)
#   adding: content/NExT-GPT/.git/logs/refs/heads/main (deflated 27%)
#   adding: content/NExT-GPT/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/NExT-GPT/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/NExT-GPT/.git/logs/refs/remotes/origin/HEAD (deflated 27%)
#   adding: content/NExT-GPT/code/ (stored 0%)
#   adding: content/NExT-GPT/code/nextgpt.png (deflated 1%)
#   adding: content/NExT-GPT/code/dataset/ (stored 0%)
#   adding: content/NExT-GPT/code/dataset/T-T+X_instruction_dataset.py (deflated 63%)
#   adding: content/NExT-GPT/code/dataset/cc3m_dataset.py (deflated 52%)
#   adding: content/NExT-GPT/code/dataset/catalog.py (deflated 88%)
#   adding: content/NExT-GPT/code/dataset/webvid_dataset.py (deflated 52%)
#   adding: content/NExT-GPT/code/dataset/preprocess_dataset.py (deflated 76%)
#   adding: content/NExT-GPT/code/dataset/utils.py (deflated 58%)
#   adding: content/NExT-GPT/code/dataset/concat_dataset.py (deflated 65%)
#   adding: content/NExT-GPT/code/dataset/__init__.py (deflated 68%)
#   adding: content/NExT-GPT/code/dataset/samplers.py (deflated 73%)
#   adding: content/NExT-GPT/code/dataset/base_dataset.py (deflated 56%)
#   adding: content/NExT-GPT/code/dataset/audiocap_dataset.py (deflated 53%)
#   adding: content/NExT-GPT/code/dataset/T+X-T_instruction_dataset.py (deflated 72%)
#   adding: content/NExT-GPT/code/header.py (deflated 55%)
#   adding: content/NExT-GPT/code/inference.py (deflated 70%)
#   adding: content/NExT-GPT/code/process_embeddings.py (deflated 70%)
#   adding: content/NExT-GPT/code/bot.png (deflated 4%)
#   adding: content/NExT-GPT/code/user.png (deflated 1%)
#   adding: content/NExT-GPT/code/config/ (stored 0%)
#   adding: content/NExT-GPT/code/config/stage_2.yaml (deflated 33%)
#   adding: content/NExT-GPT/code/config/stage_3.yaml (deflated 46%)
#   adding: content/NExT-GPT/code/config/base.yaml (deflated 64%)
#   adding: content/NExT-GPT/code/config/__init__.py (deflated 67%)
#   adding: content/NExT-GPT/code/config/stage_1.yaml (deflated 34%)
#   adding: content/NExT-GPT/code/scripts/ (stored 0%)
#   adding: content/NExT-GPT/code/scripts/app.sh (deflated 11%)
#   adding: content/NExT-GPT/code/scripts/train.sh (deflated 40%)
#   adding: content/NExT-GPT/code/train.py (deflated 65%)
#   adding: content/NExT-GPT/code/__init__.py (stored 0%)
#   adding: content/NExT-GPT/code/model/ (stored 0%)
#   adding: content/NExT-GPT/code/model/agent.py (deflated 73%)
#   adding: content/NExT-GPT/code/model/custom_sd.py (deflated 75%)
#   adding: content/NExT-GPT/code/model/custom_ad.py (deflated 74%)
#   adding: content/NExT-GPT/code/model/ImageBind/ (stored 0%)
#   adding: content/NExT-GPT/code/model/ImageBind/models/ (stored 0%)
#   adding: content/NExT-GPT/code/model/ImageBind/models/imagebind_model.py (deflated 82%)
#   adding: content/NExT-GPT/code/model/ImageBind/models/transformer.py (deflated 72%)
#   adding: content/NExT-GPT/code/model/ImageBind/models/multimodal_preprocessors.py (deflated 74%)
#   adding: content/NExT-GPT/code/model/ImageBind/models/helpers.py (deflated 66%)
#   adding: content/NExT-GPT/code/model/ImageBind/models/__init__.py (stored 0%)
#   adding: content/NExT-GPT/code/model/ImageBind/model_card.md (deflated 56%)
#   adding: content/NExT-GPT/code/model/ImageBind/CONTRIBUTING.md (deflated 45%)
#   adding: content/NExT-GPT/code/model/ImageBind/data.py (deflated 71%)
#   adding: content/NExT-GPT/code/model/ImageBind/LICENSE (deflated 69%)
#   adding: content/NExT-GPT/code/model/ImageBind/CODE_OF_CONDUCT.md (deflated 56%)
#   adding: content/NExT-GPT/code/model/ImageBind/bpe/ (stored 0%)
#   adding: content/NExT-GPT/code/model/ImageBind/bpe/bpe_simple_vocab_16e6.txt.gz (deflated 0%)
#   adding: content/NExT-GPT/code/model/ImageBind/requirements.txt (deflated 28%)
#   adding: content/NExT-GPT/code/model/ImageBind/__init__.py (deflated 36%)
#   adding: content/NExT-GPT/code/model/ImageBind/README.md (deflated 56%)
#   adding: content/NExT-GPT/code/model/layers.py (deflated 71%)
#   adding: content/NExT-GPT/code/model/qformer.py (deflated 81%)
#   adding: content/NExT-GPT/code/model/common/ (stored 0%)
#   adding: content/NExT-GPT/code/model/common/logger.py (deflated 70%)
#   adding: content/NExT-GPT/code/model/common/utils.py (deflated 86%)
#   adding: content/NExT-GPT/code/model/common/__init__.py (stored 0%)
#   adding: content/NExT-GPT/code/model/custom_vd.py (deflated 75%)
#   adding: content/NExT-GPT/code/model/modeling_llama.py (deflated 76%)
#   adding: content/NExT-GPT/code/model/__init__.py (deflated 49%)
#   adding: content/NExT-GPT/code/model/blip2.py (deflated 67%)
#   adding: content/NExT-GPT/code/model/anyToImageVideoAudio.py (deflated 85%)
#   adding: content/NExT-GPT/code/dsconfig/ (stored 0%)
#   adding: content/NExT-GPT/code/dsconfig/stage_3.json (deflated 60%)
#   adding: content/NExT-GPT/code/dsconfig/stage_2.json (deflated 60%)
#   adding: content/NExT-GPT/code/dsconfig/stage_1.json (deflated 60%)
#   adding: content/NExT-GPT/code/demo_app.py (deflated 76%)
#   adding: content/NExT-GPT/requirements.txt (deflated 39%)
#   adding: content/NExT-GPT/LICENSE.md (deflated 48%)
#   adding: content/NExT-GPT/README.md (deflated 68%)

# %%
from google.colab import files
files.download("/content/sample_data/NExT-GPT.zip")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]

image.save("astronaut_rides_horse.png")
# Out:
# Setting ds_accelerator to cuda (auto detect)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
#   0%|          | 0/50 [00:00<?, ?it/s]
